# %%
import pandas as pd
import numpy as np
import os
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

from matplotlib.image import imread
import warnings
warnings.filterwarnings('ignore')

import tensorflow as tf
from tensorflow import keras

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Conv2D,InputLayer,Reshape,MaxPooling2D,Flatten
from tensorflow.keras.callbacks import EarlyStopping

# %%
from tensorflow.keras.datasets import cifar10

(x_train, y_train), (x_test, y_test) = cifar10.load_data()

# %%
x_train.shape
# Out:
# (50000, 32, 32, 3)

# %%
x_test.shape
# Out:
# (10000, 32, 32, 3)

# %%
y_train
# Out:
# array([[6],
#        [9],
#        [9],
#        ...,
#        [9],
#        [1],
#        [1]], dtype=uint8)

# %%
x_train[0]
# Out:
# array([[[ 59,  62,  63],
#         [ 43,  46,  45],
#         [ 50,  48,  43],
#         ...,
#         [158, 132, 108],
#         [152, 125, 102],
#         [148, 124, 103]],
#
#        [[ 16,  20,  20],
#         [  0,   0,   0],
#         [ 18,   8,   0],
#         ...,
#         [123,  88,  55],
#         [119,  83,  50],
#         [122,  87,  57]],
#
#        [[ 25,  24,  21],
#         [ 16,   7,   0],
#         [ 49,  27,   8],
#         ...,
#         [118,  84,  50],
#         [120,  84,  50],
#         [109,  73,  42]],
#
#        ...,
#
#        [[208, 170,  96],
#         [201, 153,  34],
#         [198, 161,  26],
#         ...,
#         [160, 133,  70],
#         [ 56,  31,   7],
#         [ 53,  34,  20]],
#
#        [[180, 139,  96],
#         [173, 123,  42],
#         [186, 144,  30],
#         ...,
#         [184, 148,  94],
#         [ 97,  62,  34],
#         [ 83,  53,  34]],
#
#        [[177, 144, 116],
#         [168, 129,  94],
#         [179, 142,  87],
#         ...,
#         [216, 184, 140],
#         [151, 118,  84],
#         [123,  92,  72]]], dtype=uint8)

# %%
plt.imshow(x_train[3],cmap="gray")

# %%
plt.imshow(x_train[5],cmap="gray")

# %%
plt.figure()
plt.imshow(x_train[8],cmap="gray")
plt.colorbar()
plt.grid(False)
plt.show()

# %%
plt.figure(figsize=(10,10))
for i in range(25):
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(x_train[i])
plt.show()

# %%
x_train=x_train/255.0
x_test=x_test/255.0

# %%
model=Sequential()
model.add(InputLayer(input_shape=(32,32,3)))
model.add(Reshape(target_shape=(32,32,3)))
model.add(Conv2D(filters=12,kernel_size=(3,3),activation="relu"))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Flatten())
model.add(Dense(256,activation='relu'))
model.add(Dense(10,activation='softmax'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  reshape (Reshape)           (None, 32, 32, 3)         0
#
#  conv2d (Conv2D)             (None, 30, 30, 12)        336
#
#  max_pooling2d (MaxPooling2D  (None, 15, 15, 12)       0
#  )
#
#  flatten (Flatten)           (None, 2700)              0
#
#  dense (Dense)               (None, 256)               691456
#
#  dense_1 (Dense)             (None, 10)                2570
#
# =================================================================
# Total params: 694,362
# Trainable params: 694,362
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),optimizer="adam",metrics="accuracy")

# %%
model.fit(x_train, y_train, batch_size=32, epochs=10, validation_data=(x_test,y_test))
# Out:
# Epoch 1/10
# 1563/1563 [==============================] - 14s 8ms/step - loss: 1.5040 - accuracy: 0.4662 - val_loss: 1.2523 - val_accuracy: 0.5561
# Epoch 2/10
# 1563/1563 [==============================] - 13s 8ms/step - loss: 1.1890 - accuracy: 0.5818 - val_loss: 1.1512 - val_accuracy: 0.5926
# Epoch 3/10
# 1563/1563 [==============================] - 13s 8ms/step - loss: 1.0632 - accuracy: 0.6265 - val_loss: 1.1048 - val_accuracy: 0.6137
# Epoch 4/10
# 1563/1563 [==============================] - 13s 8ms/step - loss: 0.9778 - accuracy: 0.6567 - val_loss: 1.0891 - val_accuracy: 0.6192
# Epoch 5/10
# 1563/1563 [==============================] - 13s 8ms/step - loss: 0.8934 - accuracy: 0.6871 - val_loss: 1.0628 - val_accuracy: 0.6317
# Epoch 6/10
# 1563/1563 [==============================] - 13s 8ms/step - loss: 0.8219 - accuracy: 0.7105 - val_loss: 1.0850 - val_accuracy: 0.6271
# Epoch 7/10
# 1563/1563 [==============================] - 13s 9ms/step - loss: 0.7638 - accuracy: 0.7325 - val_loss: 1.0982 - val_accuracy: 0.6335
# Epoch 8/10
# 1563/1563 [==============================] - 13s 8ms/step - loss: 0.6924 - accuracy: 0.7576 - val_loss: 1.1210 - val_accuracy: 0.6322
# Epoch 9/10
# 1563/1563 [==============================] - 13s 8ms/step - loss: 0.6362 - accuracy: 0.7789 - val_loss: 1.1695 - val_accuracy: 0.6278
# Epoch 10/10
# 1563/1563 [==============================] - 13s 8ms/step - loss: 0.5783 - accuracy: 0.7969 - val_loss: 1.1951 - val_accuracy: 0.6344

# %%
summary = pd.DataFrame(model.history.history)
summary
# Out:
#        loss  accuracy  val_loss  val_accuracy
# 0  1.504043   0.46622  1.252264        0.5561
# 1  1.188977   0.58180  1.151158        0.5926
# 2  1.063174   0.62650  1.104835        0.6137
# 3  0.977776   0.65666  1.089142        0.6192
# 4  0.893373   0.68714  1.062771        0.6317
# 5  0.821882   0.71054  1.085003        0.6271
# 6  0.763792   0.73250  1.098228        0.6335
# 7  0.692421   0.75760  1.120954        0.6322
# 8  0.636215   0.77892  1.169527        0.6278
# 9  0.578306   0.79686  1.195146        0.6344

# %%
plt.figure(figsize=(10,6))
plt.plot(summary.loss, label="loss")
plt.plot(summary.val_loss, label="val_loss")
plt.legend(loc="upper right")
plt.ylabel("Loss")
plt.xlabel("Epoch")
plt.show()

# %%
plt.figure(figsize=(10,6))
plt.plot(summary.accuracy, label="accuracy")
plt.plot(summary.val_accuracy, label="val_accuracy")
plt.legend(loc="upper left")
plt.ylabel("Accuracy")
plt.xlabel("Epoch")
plt.show()

# %%
_,accuracy=model.evaluate(x_test, y_test)
# Out:
# 313/313 [==============================] - 1s 3ms/step - loss: 1.1951 - accuracy: 0.6344

# %%
accuracy
# Out:
# 0.6344000101089478
