# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
pd.set_option("display.max_columns",100)

# %%
import warnings
warnings.simplefilter('ignore')

# %%
df=pd.read_csv("LoansTrainingSet.csv")

# %%
df.head()
# Out:
#                                 Loan ID                           Customer ID  \
# 0  000025bb-5694-4cff-b17d-192b1a98ba44  5ebc8bb1-5eb9-4404-b11b-a6eebc401a19
# 1  00002c49-3a29-4bd4-8f67-c8f8fbc1048c  927b388d-2e01-423f-a8dc-f7e42d668f46
# 2  00002d89-27f3-409b-aa76-90834f359a65  defce609-c631-447d-aad6-1270615e89c4
# 3  00005222-b4d8-45a4-ad8c-186057e24233  070bcecb-aae7-4485-a26a-e0403e7bb6c5
# 4  0000757f-a121-41ed-b17b-162e76647c1f  dde79588-12f0-4811-bab0-e2b07f633fcd
#
#   Loan Status  Current Loan Amount        Term  Credit Score  \
# 0  Fully Paid                11520  Short Term         741.0
# 1  Fully Paid                 3441  Short Term         734.0
# 2  Fully Paid                21029  Short Term         747.0
# 3  Fully Paid                18743  Short Term         747.0
# 4  Fully Paid                11731  Short Term         746.0
#
#   Years in current job Home Ownership  Annual Income             Purpose  \
# ...

# %%
df.tail()
# Out:
#                                      Loan ID  \
# 256979  fffef5b7-be99-4666-ac70-2a397d2ee435
# 256980  ffffca93-aa8c-4123-b8ff-7852f6df889a
# 256981  ffffcb2e-e48e-4d2c-a0d6-ed6bce5bfdbe
# 256982  ffffcb2e-e48e-4d2c-a0d6-ed6bce5bfdbe
# 256983  ffffe32e-ed17-459f-9cfd-7b9ee7972933
#
#                                  Customer ID  Loan Status  \
# 256979  7211a8e3-cba4-4132-b939-222eed8a662c   Fully Paid
# 256980  616fef0c-8f09-4327-9b5c-48fcfaa52934   Fully Paid
# 256981  971a6682-183b-4a52-8bce-1d3429ade295  Charged Off
# 256982  971a6682-183b-4a52-8bce-1d3429ade295  Charged Off
# 256983  97281336-1e45-41d2-acb2-263ce56a590e   Fully Paid
#
#         Current Loan Amount        Term  Credit Score Years in current job  \
# 256979                 3911  Short Term           NaN              2 years
# 256980                 5078  Short Term         737.0            10+ years
# 256981                12116  Short Term        7460.0              9 years
# ...

# %%
df.sample(5)
# Out:
#                                      Loan ID  \
# 129401  80babf51-599f-40e0-a48d-42ebe4b2ee53
# 118737  75f7833e-8544-48f5-bf3a-f1be84ea01a0
# 129526  80d7f69d-8a58-4d87-84dc-acbd99330e9e
# 54772   36878c63-dfc3-4703-9611-36cfe5f5162e
# 153876  9901fe88-058d-4f7d-bdbb-5eb0453af885
#
#                                  Customer ID  Loan Status  \
# 129401  882e6d22-4dec-4461-91cc-a33a7076dd17   Fully Paid
# 118737  1c32bd3a-1d92-451f-b688-652364171143  Charged Off
# 129526  fd852d3c-f6b7-479e-a952-7fc3ab40eebb   Fully Paid
# 54772   68401e76-7d73-47aa-8aba-54c875c02fa4  Charged Off
# 153876  846cb7aa-5500-41a3-b653-eb76ce1220b7   Fully Paid
#
#         Current Loan Amount        Term  Credit Score Years in current job  \
# 129401                 9781  Short Term           NaN            10+ years
# 118737                33421  Short Term         708.0              2 years
# 129526                13924  Short Term         732.0              6 years
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 256984 entries, 0 to 256983
# Data columns (total 19 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   Loan ID                       256984 non-null  object
#  1   Customer ID                   256984 non-null  object
#  2   Loan Status                   256984 non-null  object
#  3   Current Loan Amount           256984 non-null  int64
#  4   Term                          256984 non-null  object
#  5   Credit Score                  195308 non-null  float64
#  6   Years in current job          245508 non-null  object
#  7   Home Ownership                256984 non-null  object
#  8   Annual Income                 195308 non-null  float64
#  9   Purpose                       256984 non-null  object
#  10  Monthly Debt                  256984 non-null  object
#  11  Years of Credit History       256984 non-null  float64
# ...

# %%
df.isnull().sum()
# Out:
# Loan ID                              0
# Customer ID                          0
# Loan Status                          0
# Current Loan Amount                  0
# Term                                 0
# Credit Score                     61676
# Years in current job             11476
# Home Ownership                       0
# Annual Income                    61676
# Purpose                              0
# Monthly Debt                         0
# Years of Credit History              0
# Months since last delinquent    140383
# Number of Open Accounts              0
# Number of Credit Problems            0
# Current Credit Balance               0
# Maximum Open Credit                  0
# Bankruptcies                       529
# Tax Liens                           23
# dtype: int64

# %%
df.corr()
# Out:
#                               Current Loan Amount  Credit Score  \
# Current Loan Amount                      1.000000     -0.139743
# Credit Score                            -0.139743      1.000000
# Annual Income                            0.024069     -0.033221
# Years of Credit History                  0.014725     -0.011658
# Months since last delinquent             0.003488     -0.007994
# Number of Open Accounts                 -0.003094      0.008124
# Number of Credit Problems               -0.000062      0.000777
# Current Credit Balance                   0.003138     -0.003263
# Bankruptcies                             0.003576     -0.003426
# Tax Liens                               -0.003069      0.004381
#
#                               Annual Income  Years of Credit History  \
# Current Loan Amount                0.024069                 0.014725
# Credit Score                      -0.033221                -0.011658
# ...

# %%
df.describe()
# Out:
#        Current Loan Amount   Credit Score  Annual Income  \
# count         2.569840e+05  195308.000000   1.953080e+05
# mean          1.371331e+07    1251.116099   7.195272e+04
# std           3.438131e+07    1762.016848   5.887757e+04
# min           5.050000e+02     585.000000   0.000000e+00
# 25%           8.299000e+03     714.000000   4.432100e+04
# 50%           1.429800e+04     733.000000   6.124200e+04
# 75%           2.436700e+04     744.000000   8.646200e+04
# max           1.000000e+08    7510.000000   8.713547e+06
#
#        Years of Credit History  Months since last delinquent  \
# count            256984.000000                 116601.000000
# mean                 18.290195                     34.881450
# std                   7.075747                     21.854165
# min                   3.400000                      0.000000
# 25%                  13.500000                     16.000000
# 50%                  17.000000                     32.000000
# ...

# %%
df.shape
# Out:
# (256984, 19)

# %%
plt.figure(figsize=(10,10)) #grafik boyutu
sns.heatmap(df.corr(),annot=True) #Corr grafik halinde gösterilmesi
# Out:
# <AxesSubplot:>

# %%
df.columns
# Out:
# Index(['Loan ID', 'Customer ID', 'Loan Status', 'Current Loan Amount', 'Term',
#        'Credit Score', 'Years in current job', 'Home Ownership',
#        'Annual Income', 'Purpose', 'Monthly Debt', 'Years of Credit History',
#        'Months since last delinquent', 'Number of Open Accounts',
#        'Number of Credit Problems', 'Current Credit Balance',
#        'Maximum Open Credit', 'Bankruptcies', 'Tax Liens'],
#       dtype='object')

# %%
#ortalama değer ile boş verşlerşmşzş dolduruyoruz.

# %%
df['Credit Score'].fillna(df['Credit Score'].mean(),inplace=True)
df['Annual Income'].fillna(df['Annual Income'].mean(),inplace=True)
df['Months since last delinquent'].fillna(df['Months since last delinquent'].mean(),inplace=True)
df['Tax Liens'].fillna(df['Tax Liens'].mean(),inplace=True)
df['Bankruptcies'].fillna(df['Bankruptcies'].mean(),inplace=True)

# %%
sns.countplot(x=df["Years in current job"])
# Out:
# <AxesSubplot:xlabel='Years in current job', ylabel='count'>

# %%
df['Years in current job'].value_counts()
# Out:
# 10+ years    78896
# 2 years      23462
# < 1 year     21012
# 3 years      20659
# 5 years      17864
# 1 year       16746
# 4 years      16166
# 6 years      14597
# 7 years      13968
# 8 years      12206
# 9 years       9932
# Name: Years in current job, dtype: int64

# %%
df['Years in current job'].replace('[^0-9]',"",inplace=True,regex=True)

# %%
df['Years in current job'].fillna('0',inplace=True)

# %%
df['Years in current job']=df['Years in current job'].astype(float)

# %%
df['Years in current job'].replace('0',df['Years in current job'].mean(),inplace=True)

# %%
df['Monthly Debt'].replace('[^0-9.]','',inplace=True,regex=True)
df['Monthly Debt']=df['Monthly Debt'].astype(float)

# %%
df['Maximum Open Credit'].value_counts()
# Out:
# 0        1597
# 0         234
# 10180      19
# 15662      19
# 14770      19
#          ...
# 17558       1
# 42753       1
# 29185       1
# 36222       1
# 62371       1
# Name: Maximum Open Credit, Length: 87188, dtype: int64

# %%
df['Maximum Open Credit'].replace('[a-zA-Z@_!#$%^&*()<>?/\|}{~:]',"0",inplace=True,regex=True)

# %%
df['Maximum Open Credit']=df['Maximum Open Credit'].astype(float)

# %%
df.isnull().sum()
# Out:
# Loan ID                         0
# Customer ID                     0
# Loan Status                     0
# Current Loan Amount             0
# Term                            0
# Credit Score                    0
# Years in current job            0
# Home Ownership                  0
# Annual Income                   0
# Purpose                         0
# Monthly Debt                    0
# Years of Credit History         0
# Months since last delinquent    0
# Number of Open Accounts         0
# Number of Credit Problems       0
# Current Credit Balance          0
# Maximum Open Credit             0
# Bankruptcies                    0
# Tax Liens                       0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 256984 entries, 0 to 256983
# Data columns (total 19 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   Loan ID                       256984 non-null  object
#  1   Customer ID                   256984 non-null  object
#  2   Loan Status                   256984 non-null  object
#  3   Current Loan Amount           256984 non-null  int64
#  4   Term                          256984 non-null  object
#  5   Credit Score                  256984 non-null  float64
#  6   Years in current job          256984 non-null  float64
#  7   Home Ownership                256984 non-null  object
#  8   Annual Income                 256984 non-null  float64
#  9   Purpose                       256984 non-null  object
#  10  Monthly Debt                  256984 non-null  float64
#  11  Years of Credit History       256984 non-null  float64
# ...

# %%
df=df.drop(['Loan ID','Customer ID'],axis=1)

# %%
df.head()
# Out:
#   Loan Status  Current Loan Amount        Term  Credit Score  \
# 0  Fully Paid                11520  Short Term         741.0
# 1  Fully Paid                 3441  Short Term         734.0
# 2  Fully Paid                21029  Short Term         747.0
# 3  Fully Paid                18743  Short Term         747.0
# 4  Fully Paid                11731  Short Term         746.0
#
#    Years in current job Home Ownership  Annual Income             Purpose  \
# 0                  10.0  Home Mortgage        33694.0  Debt Consolidation
# 1                   4.0  Home Mortgage        42269.0               other
# 2                  10.0  Home Mortgage        90126.0  Debt Consolidation
# 3                  10.0       Own Home        38072.0  Debt Consolidation
# 4                   4.0           Rent        50025.0  Debt Consolidation
#
#    Monthly Debt  Years of Credit History  Months since last delinquent  \
# 0        584.03                     12.3                      41.00000
# ...

# %%
df.shape
# Out:
# (256984, 17)

# %%
df.select_dtypes("object_")
# Out:
#         Loan Status        Term Home Ownership             Purpose
# 0        Fully Paid  Short Term  Home Mortgage  Debt Consolidation
# 1        Fully Paid  Short Term  Home Mortgage               other
# 2        Fully Paid  Short Term  Home Mortgage  Debt Consolidation
# 3        Fully Paid  Short Term       Own Home  Debt Consolidation
# 4        Fully Paid  Short Term           Rent  Debt Consolidation
# ...             ...         ...            ...                 ...
# 256979   Fully Paid  Short Term           Rent  Debt Consolidation
# 256980   Fully Paid  Short Term       Own Home  Debt Consolidation
# 256981  Charged Off  Short Term  Home Mortgage  Debt Consolidation
# 256982  Charged Off  Short Term  Home Mortgage  Debt Consolidation
# 256983   Fully Paid   Long Term  Home Mortgage  Debt Consolidation
#
# [256984 rows x 4 columns]

# %%
df['Home Ownership'].value_counts()
# Out:
# Home Mortgage    124477
# Rent             109010
# Own Home          22923
# HaveMortgage        574
# Name: Home Ownership, dtype: int64

# %%
df['Home Ownership'].replace(['HaveMortgage','Home Mortgage'],'Mortgage',inplace=True)

# %%
df['Home Ownership'].value_counts()
# Out:
# Mortgage    125051
# Rent        109010
# Own Home     22923
# Name: Home Ownership, dtype: int64

# %%
d={"Mortgage":1,"Rent":0,"Own Home":2,}

# %%
df["Home Ownership"]=df["Home Ownership"].map(d)

# %%
df['Purpose'].value_counts()
# Out:
# Debt Consolidation      203911
# Home Improvements        14915
# other                    14268
# Other                     9667
# Business Loan             4712
# Buy a Car                 3276
# Medical Bills             2868
# Take a Trip               1570
# Buy House                 1530
# Educational Expenses       267
# Name: Purpose, dtype: int64

# %%
df['Purpose'].replace('other','Other',inplace=True)

# %%
df['Purpose'].value_counts()
# Out:
# Debt Consolidation      203911
# Other                    23935
# Home Improvements        14915
# Business Loan             4712
# Buy a Car                 3276
# Medical Bills             2868
# Take a Trip               1570
# Buy House                 1530
# Educational Expenses       267
# Name: Purpose, dtype: int64

# %%
e={"Debt Consolidation":1,"Other":0,"Home Improvements":2,"Business Loan":3,"Buy a Car":4,"Medical Bills":5,"Take a Trip":6,"Buy House":7,"Buy House":8,"Educational Expenses":9,}

# %%
df["Purpose"]=df["Purpose"].map(e)

# %%
df['Term'].value_counts()
# Out:
# Short Term    192632
# Long Term      64352
# Name: Term, dtype: int64

# %%
e={"Short Term":1,"Long Term":0,}

# %%
df["Term"]=df["Term"].map(e)

# %%
df['Loan Status'].value_counts()
# Out:
# Fully Paid     176191
# Charged Off     80793
# Name: Loan Status, dtype: int64

# %%
f={"Fully Paid":1,"Charged Off":0}

# %%
df["Loan Status"]=df["Loan Status"].map(f)

# %%
df["Loan Status"]
# Out:
# 0         1
# 1         1
# 2         1
# 3         1
# 4         1
#          ..
# 256979    1
# 256980    1
# 256981    0
# 256982    0
# 256983    1
# Name: Loan Status, Length: 256984, dtype: int64

# %%
x,y=df.drop('Loan Status',axis=1),df[['Loan Status']]

# %%
x=pd.get_dummies(x,drop_first=True)

# %%
y=pd.get_dummies(y,drop_first=True)

# %%
x.isnull().sum()
# Out:
# Current Loan Amount             0
# Term                            0
# Credit Score                    0
# Years in current job            0
# Home Ownership                  0
# Annual Income                   0
# Purpose                         0
# Monthly Debt                    0
# Years of Credit History         0
# Months since last delinquent    0
# Number of Open Accounts         0
# Number of Credit Problems       0
# Current Credit Balance          0
# Maximum Open Credit             0
# Bankruptcies                    0
# Tax Liens                       0
# dtype: int64

# %%
x.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 256984 entries, 0 to 256983
# Data columns (total 16 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   Current Loan Amount           256984 non-null  int64
#  1   Term                          256984 non-null  int64
#  2   Credit Score                  256984 non-null  float64
#  3   Years in current job          256984 non-null  float64
#  4   Home Ownership                256984 non-null  int64
#  5   Annual Income                 256984 non-null  float64
#  6   Purpose                       256984 non-null  int64
#  7   Monthly Debt                  256984 non-null  float64
#  8   Years of Credit History       256984 non-null  float64
#  9   Months since last delinquent  256984 non-null  float64
#  10  Number of Open Accounts       256984 non-null  int64
#  11  Number of Credit Problems     256984 non-null  int64
# ...

# %%
x.head()
# Out:
#    Current Loan Amount  Term  Credit Score  Years in current job  \
# 0                11520     1         741.0                  10.0
# 1                 3441     1         734.0                   4.0
# 2                21029     1         747.0                  10.0
# 3                18743     1         747.0                  10.0
# 4                11731     1         746.0                   4.0
#
#    Home Ownership  Annual Income  Purpose  Monthly Debt  \
# 0               1        33694.0        1        584.03
# 1               1        42269.0        0       1106.04
# 2               1        90126.0        1       1321.85
# 3               2        38072.0        1        751.92
# 4               0        50025.0        1        355.18
#
#    Years of Credit History  Months since last delinquent  \
# 0                     12.3                      41.00000
# 1                     26.3                      34.88145
# 2                     28.8                      34.88145
# ...

# %%
y.shape,x.shape
# Out:
# ((256984, 1), (256984, 16))

# %%
from sklearn.model_selection import train_test_split

# %%
def classification_funct(x,y):
    from sklearn.naive_bayes import GaussianNB
    from sklearn.naive_bayes import BernoulliNB
    from sklearn.svm import SVC
    from sklearn.neighbors import KNeighborsClassifier
    from sklearn.tree import DecisionTreeClassifier
    from sklearn.ensemble import RandomForestClassifier
    from sklearn.linear_model import LogisticRegression
    from sklearn.ensemble import GradientBoostingClassifier

    from sklearn.metrics import accuracy_score,precision_score,recall_score,f1_score
    from sklearn.metrics import confusion_matrix,classification_report
              
    g=GaussianNB()
    b=BernoulliNB()
    KN=KNeighborsClassifier()
    SVC=SVC() 
    D=DecisionTreeClassifier()
    R=RandomForestClassifier()
    Log=LogisticRegression()
    G=GradientBoostingClassifier()
      
    x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=13)
    
    
    algos=[g,b,KN,SVC,D,R,Log,G]
    algo_names=['GaussianNB','BernoulliNB','KNeighborsClassifier','SVC','DecisionTreeClassifier','RandomForestClassifier','LogisticRegression','GradientBoostingClassifier']
    
    accuracy_scored=[]
    precision_scored=[]
    recall_scored=[]
    f1_scored=[]
        
    print(x_train.shape,x_test.shape,y_train.shape,y_test.shape)
    
    for item in algos:

        predict=item.fit(x_train,y_train).predict(x_test)
        
        
        accuracy_scored.append(accuracy_score(y_test,predict))
        precision_scored.append(precision_score(y_test,predict))
        recall_scored.append(recall_score(y_test,predict))
        f1_scored.append(f1_score(y_test,predict))

    result=pd.DataFrame(columns=['accuracy_score','f1_score','recall_score','precision_score'],index=algo_names)
    result['accuracy_score']=accuracy_scored
    result['f1_score']=f1_scored
    result['recall_score']=recall_scored
    result['precision_score']=precision_scored
    
    return result.sort_values('accuracy_score',ascending=False)

# %%
classification_funct(x,y)
# Out:
# (192738, 16) (64246, 16) (192738, 1) (64246, 1)
#                             accuracy_score  f1_score  recall_score  \
# RandomForestClassifier            0.835647  0.887533      0.944290
# GradientBoostingClassifier        0.764079  0.847046      0.951225
# DecisionTreeClassifier            0.754771  0.816026      0.791936
# LogisticRegression                0.746350  0.841903      0.983432
# KNeighborsClassifier              0.720045  0.805275      0.842909
# BernoulliNB                       0.688292  0.812526      0.983591
# SVC                               0.686751  0.814288      1.000000
# GaussianNB                        0.450907  0.334459      0.200902
#
#                             precision_score
# RandomForestClassifier             0.837212
# GradientBoostingClassifier         0.763434
# DecisionTreeClassifier             0.841627
# LogisticRegression                 0.735985
# KNeighborsClassifier               0.770857
# BernoulliNB                        0.692148
# ...
